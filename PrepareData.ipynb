# %%
import rdkit
from rdkit import Chem
import requests
import json
from collections import Counter
from rdkit.Chem import AllChem
from rdkit.Chem import Draw
import pandas as pd

# %%
ChemSoft_ = requests.get("https://chemsoft.biocad.ru/api/reactions/catalog?IncludeCompleted=true&archivedOnly=true&limit=1024", headers = {'Authorization': 'JWT eyJleHAiOjE1MjY2Mzg0NzMsInR5cCI6IkpXVCIsImFsZyI6IkhTNTEyIn0..BMQI0LRbn5Bu881A9UqoBXPZoUB0uvXD-K10j5AaHsflr1yr8vYGf8L21ijxnY1YSIwfD4x06BnbP4AAgjX0zg'})
ChemSoft = ChemSoft_.json()
reaction_df = pd.DataFrame(ChemSoft)
new_df = pd.DataFrame()

# %%
reaction_df
# Out:
#           Author CandidateId                      CreationDate  \
# 0    student_dvb        None     2018-04-28T14:26:58.092+03:00
# 1    student_dvb        None     2018-04-28T14:58:45.707+03:00
# 2    student_dvb        None     2018-04-28T15:03:58.271+03:00
# 3    student_dvb        None   2018-04-28T15:05:05.18163+03:00
# 4    student_dvb        None  2018-04-28T15:06:12.568343+03:00
# 5    student_dvb        None   2018-04-28T15:10:23.62401+03:00
# 6    student_dvb        None   2018-04-28T15:13:21.32712+03:00
# 7    student_dvb        None  2018-04-28T15:16:16.446326+03:00
# 8    student_dvb        None  2018-04-28T15:24:11.981443+03:00
# 9    student_dvb        None      2018-04-28T15:25:43.74+03:00
# 10   student_dvb        None  2018-04-28T15:27:46.262687+03:00
# 11   student_dvb        None  2018-04-28T15:31:23.596663+03:00
# 12   student_dvb        None     2018-04-28T15:33:20.607+03:00
# 13   student_dvb        None     2018-04-28T15:36:38.887+03:00
# ...

# %%
new_df['ExperimentalYield'] = reaction_df['ExperimentalYield']
new_df['Name'] = reaction_df['Name']
new_df['Reagents'] = reaction_df.loc[:, "Reagents"].apply(lambda l: [e["SmilesFormula"] for e in l])
new_df['Products'] = reaction_df.loc[:, "Products"].apply(lambda l: [e["SmilesFormula"] for e in l])
new_rct_series = new_df["Reagents"].apply(lambda l: ".".join(l))
new_prd_series = new_df["Products"].apply(lambda l: ".".join(l))

# %%
def canon(df):
    df_1 = []    
    for smiles in df:
        try:
            canon = Chem.CanonSmiles(smiles)
            df_1.append(canon)
        except:    
            mol = Chem.MolFromSmiles(smiles, sanitize=False)
            rea = AllChem.ReactionFromSmarts("[n:1]([O-:2]):[o:3]>>[N+:1]([O-:2])=[O:3]")
            rea.Initialize()
            mol = Chem.MolToSmiles(rea.RunReactants([mol])[0][0])
            try:
                canon = Chem.CanonSmiles(mol)
                df_1.append(canon)
            except:
                if '[n+]' in mol:
                     mol = mol.replace('[n+]', '[N+]') 
                if '(:o)' in mol:
                    mol = mol.replace('(:o)', '(=O)')
                if 'o' in mol:
                     mol = mol.replace('o', 'O')
                canon = Chem.CanonSmiles(mol)
                df_1.append(canon)
    return df_1

# %%
new_df['ReagentsCanon'] = new_df['Reagents'].apply(canon)
new_df['ProductsCanon'] = new_df['Products'].apply(canon)

# %%
new_df
# Out:
#      ExperimentalYield            Name  \
# 0                0.000    CDK8-ACh-151
# 1                0.110     BTK-ACh-245
# 2                0.730     BTK-ACh-269
# 3                5.100     BTK-ACh-382
# 4                0.220     BTK-ACh-246
# 5                1.350     BTK-ACh-383
# 6                0.000     BTK-ACh-247
# 7                0.000     BTK-ACh-384
# 8                0.358     BTK-ACh-248
# 9                0.136     BTK-ACh-270
# 10               3.780     BTK-ACh-385
# 11               0.000     BTK-ACh-386
# 12               0.090     BTK-ACh-249
# 13                 NaN     BTK-ACh-271
# 14               0.000     BTK-ACh-250
# 15               0.000     BTK-ACh-388
# 16               3.710     BTK-ACh-387
# 17               0.021     BTK-ACh-251
# 18                 NaN     BTK-ACh-272
# 19               0.000     BTK-ACh-252
# 20               1.330     BTK-ACh-389
# 21               0.630     BTK-ACh-273
# 22                 NaN     BTK-ACh-253
# ...

# %%
dict_prod = dict()
reaction_dicts = []
for row in new_df.iterrows():
    for elem in row[1]['ProductsCanon']:
        reaction_dict = {'Product':elem, 'Reagent': row[1]['ReagentsCanon'], 'ExperimentalYield': row[1]['ExperimentalYield'], 'Name': row[1]['Name']}
        reaction_dicts.append(reaction_dict)

reaction_df = pd.DataFrame(reaction_dicts)

new_reag = reaction_df["Reagent"].apply(lambda f: ".".join(f))
reaction_df.loc[:, "ReactionSmiles"] = new_reag + ">>" + reaction_df["Product"]

del reaction_df['Product']
del reaction_df['Reagent']

# %%
reaction_df
# Out:
#      ExperimentalYield            Name  \
# 0                0.000    CDK8-ACh-151
# 1                0.110     BTK-ACh-245
# 2                0.730     BTK-ACh-269
# 3                5.100     BTK-ACh-382
# 4                0.220     BTK-ACh-246
# 5                1.350     BTK-ACh-383
# 6                0.000     BTK-ACh-247
# 7                0.000     BTK-ACh-384
# 8                0.358     BTK-ACh-248
# 9                0.136     BTK-ACh-270
# 10               3.780     BTK-ACh-385
# 11               0.000     BTK-ACh-386
# 12               0.090     BTK-ACh-249
# 13                 NaN     BTK-ACh-271
# 14               0.000     BTK-ACh-250
# 15               0.000     BTK-ACh-388
# 16               3.710     BTK-ACh-387
# 17               0.021     BTK-ACh-251
# 18                 NaN     BTK-ACh-272
# 19               0.000     BTK-ACh-252
# 20               1.330     BTK-ACh-389
# 21               0.630     BTK-ACh-273
# 22                 NaN     BTK-ACh-253
# ...

# %%
def group_reactions(yields):
    if any([elem > 0 for elem in yields]):
        return 1
    elif all([elem == 0 for elem in yields]):
        return 0 
    else:
        return -1

# %%
# reaction_df_agg = reaction_df.groupby('ReactionSmiles').agg({"ExperimentalYield": group_reactions})
# reaction_df_agg = reaction_df_agg.rename(columns={'ExperimentalYield': 'Flag'})
# reaction_df_agg.to_csv('reaction_df_new.csv', sep='\t')
# reaction_df
reaction_df_with_names = reaction_df.groupby('ReactionSmiles').agg({"ExperimentalYield": group_reactions, "Name":'sum'})
reaction_df_with_names  = reaction_df_with_names.rename(columns={'ExperimentalYield': 'Flag'})
reaction_df_with_names.to_csv('auto.csv', sep = ',')

# %%
reaction_df_with_names
# Out:
#                                                     Flag  \
# ReactionSmiles
# Br.NCCBr.CC(C)(C)OC(=O)OC(=O)OC(C)(C)C>>CC(C)(C...   1.0
# Brc1ccc(I)cc1.Cn1cc(B2OC(C)(C)C(C)(C)O2)cn1>>Cn...   1.0
# Brc1cccc2cc[nH]c12.CC(C)(C)OC=O>>CC(C)(C)OC(=O)...   1.0
# Brc1cccc2cc[nH]c12.CC1(C)OB(B2OC(C)(C)C(C)(C)O2...  -1.0
# Brc1cccc2cc[nH]c12.C[Si](C)(C)CCOCl>>C[Si](C)(C...   1.0
# Brc1cccc2cc[nH]c12.O=Cc1cccnc1>>OC(c1cccnc1)c1c...  -1.0
# Brc1cnc2[nH]cc(I)c2c1.C[Si](C)(C)CCOCCl>>C[Si](...   1.0
# Brc1cnc2[nH]ccc2c1>>Brc1cnc2[nH]cc(I)c2c1            1.0
# C=CC(=O)Nc1cc(N)c(OC)cc1N(C)CCN(C)C.C=CC(=O)Nc1...   1.0
# C=Cc1ccc2ccccc2c1>>O=C(CBr)c1ccc2ccccc2c1           -1.0
# C=Cc1ccc2ccccc2c1>>OC(CBr)c1ccc2ccccc2c1             1.0
# CC(=O)c1nc(Cl)ccc1N.CC(C)(C)OC(=O)OC(=O)OC(C)(C...   0.0
# CC(C)(C)OC(=O)N1CC(Cn2nc(-c3ccc(C(=O)Nc4ccccn4)...   1.0
# CC(C)(C)OC(=O)N1CC(Cn2nc(-c3ccc(Oc4ccncc4)cc3)c...   1.0
# CC(C)(C)OC(=O)N1CC(n2nc(-c3ccc(C(=O)Nc4ccccn4)c...   1.0
# ...

# %%
df_1 = pd.read_csv('auto.csv', sep = ',')
df_1['ReactionSmiles']
divided_reactions = df_1["ReactionSmiles"].apply(lambda f: f.split(">>"))
products1_list = []
for elem in divided_reactions:
    products1_list.append(elem[1])
df_1['Product'] = products1_list
# Out:
#                                         ReactionSmiles  Flag  \
# 0    Br.NCCBr.CC(C)(C)OC(=O)OC(=O)OC(C)(C)C>>CC(C)(...   1.0
# 1    Brc1ccc(I)cc1.Cn1cc(B2OC(C)(C)C(C)(C)O2)cn1>>C...   1.0
# 2    Brc1cccc2cc[nH]c12.CC(C)(C)OC=O>>CC(C)(C)OC(=O...   1.0
# 3    Brc1cccc2cc[nH]c12.CC1(C)OB(B2OC(C)(C)C(C)(C)O...  -1.0
# 4    Brc1cccc2cc[nH]c12.C[Si](C)(C)CCOCl>>C[Si](C)(...   1.0
# 5    Brc1cccc2cc[nH]c12.O=Cc1cccnc1>>OC(c1cccnc1)c1...  -1.0
# 6    Brc1cnc2[nH]cc(I)c2c1.C[Si](C)(C)CCOCCl>>C[Si]...   1.0
# 7            Brc1cnc2[nH]ccc2c1>>Brc1cnc2[nH]cc(I)c2c1   1.0
# 8    C=CC(=O)Nc1cc(N)c(OC)cc1N(C)CCN(C)C.C=CC(=O)Nc...   1.0
# 9            C=Cc1ccc2ccccc2c1>>O=C(CBr)c1ccc2ccccc2c1  -1.0
# 10            C=Cc1ccc2ccccc2c1>>OC(CBr)c1ccc2ccccc2c1   1.0
# 11   CC(=O)c1nc(Cl)ccc1N.CC(C)(C)OC(=O)OC(=O)OC(C)(...   0.0
# 12   CC(C)(C)OC(=O)N1CC(Cn2nc(-c3ccc(C(=O)Nc4ccccn4...   1.0
# 13   CC(C)(C)OC(=O)N1CC(Cn2nc(-c3ccc(Oc4ccncc4)cc3)...   1.0
# ...

# %%
list_of_dicts = []
for elem in set(df_1.Product):
    reactions_dict = dict()
    list_reactions = []
    flag = []
    reactions = df_1.loc[df_1['Product'] == elem, ['ReactionSmiles', 'Flag']]
    for react in reactions['ReactionSmiles']:
        list_reactions.append(react)
    for flzok in reactions['Flag']:
        flag.append(flzok)
    reactions_dict = {'Product': elem, 'ReactionSmiles': list_reactions, 'Flag': flag}
    list_of_dicts.append(reactions_dict)
df = pd.DataFrame(list_of_dicts)
df.to_csv('Auto_group_products_with_group_reactions_df.csv', sep = ',', index = False)
